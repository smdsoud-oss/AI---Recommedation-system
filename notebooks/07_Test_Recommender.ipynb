# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# c:\Users\mohammed soud\AI-Electronics-Accessories-Recommendation-System\notebooks

# %%
import sys
import os

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Project Root:", project_root)
print("src exists:", os.path.exists(os.path.join(project_root, "src")))
# Out:
# Project Root: c:\Users\mohammed soud\AI-Electronics-Accessories-Recommendation-System
# src exists: True

# %%
import os

print(os.listdir(os.path.join(project_root, "src")))
# Out:
# ['config.py', 'data_preprocessing', 'embedding', 'image_downloader', 'recommendation', 'utils', '__init__.py', '__pycache__']

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\mohammed soud\AI-Electronics-Accessories-Recommendation-System\notebooks

# %%
import os

print(os.listdir("../src/embedding"))
# Out:
# ['clip_model.py', '__init__.py']

# %%
import sys
import os

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(project_root)
# Out:
# c:\Users\mohammed soud\AI-Electronics-Accessories-Recommendation-System

# %%
from src.embedding.clip_model import load_clip_model

model, preprocess, device = load_clip_model()

print(device)
# Out:
# cpu

# %%
import sys
import os

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(project_root)
# Out:
# c:\Users\mohammed soud\AI-Electronics-Accessories-Recommendation-System

# %%
from src.embedding.clip_model import load_clip_model

model, preprocess, device = load_clip_model()

print(device)
# Out:
# cpu
